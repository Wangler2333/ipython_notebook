# %% [markdown]
# ## WSGI（协议）

# %% [markdown]
# - WSGI需要基于一个web服务器运行
# ![%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-03-11%20%E4%B8%8A%E5%8D%8810.24.44.png](attachment:%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-03-11%20%E4%B8%8A%E5%8D%8810.24.44.png)

# %% [markdown]
# - 当浏览器请求一个动态页面时，http服务器调用web框架处理请求，返回web框架处理的结果
# - 当浏览器请求一个静态页面时，http服务器直接调用静态资源返回

# %% [markdown]
# ### 协议内容
# - 默认调用application()函数
# - 传入/传出
# - 传入：1.字典 2.函数引用
# - 返回：1.application()函数调用传入的函数引用，设置header 2.application()函数return body
