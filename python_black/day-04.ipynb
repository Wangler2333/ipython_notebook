# %% [markdown]
# - 2018年1月8日 传智黑马
# - 晴，温度还好，想赖床～
# - GitHub地址：https://github.com/Wangler2333/ipython_notebook/tree/master/python_black
# - 浏览地址：https://nbviewer.jupyter.org/github/Wangler2333/ipython_notebook/blob/master/python_black/day-04.ipynb

# %% [markdown]
# ### 上午
# - 今天拜读了数据结构中关于线性表的链式存储结构，关于在c语言中如何实现已了解，但对如何在python中实现进行了一下思考

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-01-08%20%E4%B8%8B%E5%8D%883.09.42.png](attachment:%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-01-08%20%E4%B8%8B%E5%8D%883.09.42.png)

# %% [markdown]
# - 由于python中无法使用指针，但由于变量的动态定义的关系，完全可以用变量实现“伪指针”。
# - 重新自建一个类，用变量代替指针，实现链表结构
# - 相关资料：https://www.cnblogs.com/king-ding/p/pythonchaintable.html
